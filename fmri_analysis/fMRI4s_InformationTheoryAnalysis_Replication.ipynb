# %% [markdown]
# # Master1 - Empirical fMRI analyses, replication cohort
#
# ## Takuya Ito
# #### 04/18/2019

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import multiprocessing as mp
import scipy.stats as stats
os.environ['OMP_NUM_THREADS'] = str(1)
import statsmodels.sandbox.stats.multicomp as mc
import sklearn
import seaborn as sns
plt.style.use("ggplot")
sns.set_style('whitegrid')
plt.rcParams["font.family"] = "FreeSans"
import nibabel as nib
import pandas as pd
import sys
sys.path.append('glmScripts/')
import taskGLMPipeline as tgp
import h5py
import dimensionality
sys.path.append('bctpy/')
import bct

# %% [markdown]
# ## Set-up subject list and construct global variables

# %%
## Exploratory subjects
# subjNums = ['178950','189450','199453','209228','220721','298455','356948','419239','499566','561444','618952','680452','757764','841349','908860',
#             '103818','113922','121618','130619','137229','151829','158035','171633','179346','190031','200008','210112','221319','299154','361234',
#             '424939','500222','570243','622236','687163','769064','845458','911849','104416','114217','122317','130720','137532','151930','159744',
#             '172029','180230','191235','200614','211316','228434','300618','361941','432332','513130','571144','623844','692964','773257','857263',
#             '926862','105014','114419','122822','130821','137633','152427','160123','172938','180432','192035','200917','211417','239944','303119',
#             '365343','436239','513736','579665','638049','702133','774663','865363','930449','106521','114823','123521','130922','137936','152831',
#             '160729','173334','180533','192136','201111','211619','249947','305830','366042','436845','516742','580650','645450','715041','782561',
#             '871762','942658','106824','117021','123925','131823','138332','153025','162026','173536','180735','192439','201414','211821','251833',
#             '310621','371843','445543','519950','580751','647858','720337','800941','871964','955465','107018','117122','125222','132017','138837',
#             '153227','162329','173637','180937','193239','201818','211922','257542','314225','378857','454140','523032','585862','654350','725751',
#             '803240','872562','959574','107422','117324','125424','133827','142828','153631','164030','173940','182739','194140','202719','212015',
#             '257845','316633','381543','459453','525541','586460','654754','727553','812746','873968','966975']

## Validation subjects
subjNums = ['100206','108020','117930','126325','133928','143224','153934','164636','174437','183034','194443','204521','212823','268749','322224',
            '385450','463040','529953','587664','656253','731140','814548','877269','978578','100408','108222','118124','126426','134021','144832',
            '154229','164939','175338','185139','194645','204622','213017','268850','329844','389357','467351','530635','588565','657659','737960',
            '816653','878877','987074','101006','110007','118225','127933','134324','146331','154532','165638','175742','185341','195445','205119',
            '213421','274542','341834','393247','479762','545345','597869','664757','742549','820745','887373','989987','102311','111009','118831',
            '128632','135528','146432','154936','167036','176441','186141','196144','205725','213522','285345','342129','394956','480141','552241',
            '598568','671855','744553','826454','896879','990366','102513','112516','118932','129028','135629','146533','156031','167440','176845',
            '187850','196346','205826','214423','285446','348545','395756','481042','553344','599671','675661','749058','832651','899885','991267',
            '102614','112920','119126','129129','135932','147636','157336','168745','177645','188145','198350','208226','214726','286347','349244',
            '406432','486759','555651','604537','679568','749361','835657','901442','992774','103111','113316','120212','130013','136227','148133',
            '157437','169545','178748','188549','198451','208327','217429','290136','352738','414229','497865','559457','615744','679770','753150',
            '837560','907656','993675','103414','113619','120414','130114','136833','150726','157942','171330']

basedir = '/projects3/TaskFCMech/'

# Using final partition
networkdef = np.loadtxt('/projects3/NetworkDiversity/data/network_partition.txt')
networkorder = np.asarray(sorted(range(len(networkdef)), key=lambda k: networkdef[k]))
networkorder.shape = (len(networkorder),1)
# network mappings for final partition set
networkmappings = {'fpn':7, 'vis1':1, 'vis2':2, 'smn':3, 'aud':8, 'lan':6, 'dan':5, 'con':4, 'dmn':9, 
                   'pmulti':10, 'none1':11, 'none2':12}
networks = networkmappings.keys()

xticks = {}
reorderednetworkaffil = networkdef[networkorder]
for net in networks:
    netNum = networkmappings[net]
    netind = np.where(reorderednetworkaffil==netNum)[0]
    tick = np.max(netind)
    xticks[tick] = net

## General parameters/variables
nParcels = 360
nSubjs = len(subjNums)

glasserfile2 = '/projects/AnalysisTools/ParcelsGlasser2016/Q1-Q6_RelatedParcellation210.LR.CorticalAreas_dil_Colors.32k_fs_RL.dlabel.nii'
glasser2 = nib.load(glasserfile2).get_data()
glasser2 = np.squeeze(glasser2)

sortednets = np.sort(xticks.keys())
orderednetworks = []
for net in sortednets: orderednetworks.append(xticks[net])
    
networkpalette = ['royalblue','slateblue','paleturquoise','darkorchid','limegreen',
                  'lightseagreen','yellow','orchid','r','peru','orange','olivedrab']
networkpalette = np.asarray(networkpalette)

OrderedNetworks = ['VIS1','VIS2','SMN','CON','DAN','LAN','FPN','AUD','DMN','PMM','VMM','ORA']

tasks = {'EMOTION':[0,1],
     'GAMBLING':[2,3],
     'LANGUAGE':[4,5],
     'MOTOR':[6,7,8,9,10,11],
     'RELATIONAL':[12,13],
     'SOCIAL':[14,15],
     'WM':[16,17,18,19,20,21,22,23]}
taskNames = ['EMOTION', 'GAMBLING', 'LANGUAGE', 'MOTOR', 'RELATIONAL', 'SOCIAL', 'WM']
TRsPerRun = [176,176,253,253,316,316,284,284,232,232,274,274,405,405]
restRuns = ['rfMRI_REST1_RL', 'rfMRI_REST1_LR','rfMRI_REST2_RL', 'rfMRI_REST2_LR']
taskRuns= ['tfMRI_EMOTION_RL','tfMRI_EMOTION_LR','tfMRI_GAMBLING_RL','tfMRI_GAMBLING_LR',
           'tfMRI_LANGUAGE_RL','tfMRI_LANGUAGE_LR','tfMRI_MOTOR_RL','tfMRI_MOTOR_LR',
           'tfMRI_RELATIONAL_RL','tfMRI_RELATIONAL_LR','tfMRI_SOCIAL_RL','tfMRI_SOCIAL_LR','tfMRI_WM_RL','tfMRI_WM_LR']

# %% [markdown]
# # 0.0 Define functions for loading data

# %%
def loadRestResiduals(subj,model='24pXaCompCorXVolterra',zscore=False,FIR=False):
    datafile = '/projects3/TaskFCMech/data/hcppreprocessedmsmall/hcpPostProcCiric/' + subj + '_glmOutput_data.h5' 
    h5f = h5py.File(datafile,'r')
    data = []
    if FIR:
        dataid = 'rfMRI_REST_' + model + '_taskReg_resid_FIR'
        data = h5f['taskRegression'][dataid][:]
        if zscore:
            # Zscore each run separately
            runstart = 0
            for run in range(4):
                runend = runstart + 1195
                data[:,runstart:runend] = stats.zscore(data[:,runstart:runend],axis=1)
                runstart += 1195
                
            # Now z-score rest time series as if it were task
            trcount = 0
            for ntrs in TRsPerRun:
                trstart = trcount
                trend = trcount + ntrs
                data[:,trstart:trend] = stats.zscore(data[:,trstart:trend],axis=1)

                trcount += ntrs

        data = data.T
    else:
        for run in restRuns:
            dataid = run + '/nuisanceReg_resid_' + model
            tmp = h5f[dataid][:]
            tmp = stats.zscore(tmp,axis=1)
            data.extend(tmp.T)
    data = np.asarray(data).T
    h5f.close()
    return data

def loadTaskActivity(subj,model='24pXaCompCorXVolterra',zscore=False):
    datafile = '/projects3/TaskFCMech/data/hcppreprocessedmsmall/hcpPostProcCiric/' + subj + '_glmOutput_data.h5' 
    h5f = h5py.File(datafile,'r')
    betas = []
    for task in taskNames:
        dataid = 'tfMRI_' + task + '_' + model + '_taskReg_betas_canonical'
        tmp = h5f['taskRegression'][dataid][:]
        betas.extend(tmp[:,1:].T)
    betas = np.asarray(betas).T
    h5f.close()
    return betas

def loadTaskResiduals(subj, model='24pXaCompCorXVolterra', taskModel='FIR', zscore=False):
    datafile = '/projects3/TaskFCMech/data/hcppreprocessedmsmall/hcpPostProcCiric/' + subj + '_glmOutput_data.h5'         
    h5f = h5py.File(datafile,'r')
    resids = []
    for task in taskNames:
        dataid = 'tfMRI_' + task + '_' + model + '_taskReg_resid_' + taskModel
        tmp = h5f['taskRegression'][dataid][:]
        if zscore:
            nTRsPerRun = tmp.shape[1]/2
            tmp[:,:nTRsPerRun] = stats.zscore(tmp[:,:nTRsPerRun],axis=1)
            tmp[:,nTRsPerRun:] = stats.zscore(tmp[:,nTRsPerRun:],axis=1)
        resids.extend(tmp.T)
    resids = np.asarray(resids).T
    h5f.close()
    return resids

# %% [markdown]
# ### Main parameters

# %%
model = '24pXaCompCorXVolterra'
zscore = True
FIR = True

# %% [markdown]
# # 1.0 Identify number of significantly active regions for each task, relative to 0

# %% [markdown]
# ## Load rest and task data time series

# %%
nTasks = 24
restTS = np.zeros((nParcels,4780,len(subjNums)))
restTS = np.zeros((nParcels,3810,len(subjNums)))
taskTS = np.zeros((nParcels,3810,len(subjNums)))
task_timing = np.zeros((3810,nTasks,len(subjNums)))
scount = 0
for subj in subjNums:
    if scount%25==0: print 'Loading in data for subject', scount+1, '/', len(subjNums)
    restTS[:,:,scount] = loadRestResiduals(subj,model=model,zscore=zscore,FIR=FIR)
    taskTS[:,:,scount] = loadTaskResiduals(subj, model=model, taskModel='FIR', zscore=zscore) # We make this FIR since we only want to use FIR regressed task residuals for FC analysis
    task_timing[:,:,scount] = tgp.loadTaskTimingForAllTasks(subj,taskModel='canonical')['taskRegressors']>.5 # Only to obtain which time points to estimate FC with
    scount += 1
    
task_timing = task_timing.astype(bool)
# Out:
# Loading in data for subject 1 / 176
# Loading in data for subject 26 / 176
# Loading in data for subject 51 / 176
# Loading in data for subject 76 / 176
# Loading in data for subject 101 / 176
# Loading in data for subject 126 / 176
# Loading in data for subject 151 / 176
# Loading in data for subject 176 / 176

# %% [markdown]
# # Calculate mutual information between all pairs of regions

# %%
from sklearn.metrics import mutual_info_score
def calc_MI((x, y, bins)):
    c_xy = np.histogram2d(x, y, bins)[0]
    mi = mutual_info_score(None, None, contingency=c_xy)
    return mi

# %%
mi_mat_task = np.zeros((nParcels,nParcels,len(subjNums)))
mi_mat_rest = np.zeros((nParcels,nParcels,len(subjNums)))
df_mi = {}
df_mi['State'] = []
df_mi['Subject'] = []
df_mi['Mutual Information'] = []
bins = 10
nproc = 20
for scount in range(len(subjNums)):
    print('Calc MI FC matrix for subject',scount)
    taskGeneralTiming = np.sum(task_timing[:,:,scount],axis=1)>0
    inputs_rest = []
    inputs_task = []
    for i in range(nParcels):
        for j in range(nParcels):
            if i <= j: continue
            
            inputs_rest.append((restTS[i,taskGeneralTiming,scount],restTS[j,taskGeneralTiming,scount],bins))
            inputs_task.append((taskTS[i,taskGeneralTiming,scount],restTS[j,taskGeneralTiming,scount],bins))
            
    pool = mp.Pool(processes=nproc)
    results_rest = pool.map_async(calc_MI,inputs_rest).get()
    pool.close()
    pool.join()
    
    pool = mp.Pool(processes=nproc)
    results_task = pool.map_async(calc_MI,inputs_task).get()
    pool.close()
    pool.join()
    
    count = 0
    for i in range(nParcels):
        for j in range(nParcels):
            if i<=j: continue
            
            mi_mat_rest[i,j,scount] = results_rest[count] 
            mi_mat_task[i,j,scount] = results_task[count] 
            count += 1
            
    df_mi['State'].append('Rest')
    df_mi['Subject'].append(subjNums[scount])
    df_mi['Mutual Information'].append(np.mean(results_rest))
    
    df_mi['State'].append('Task')
    df_mi['Subject'].append(subjNums[scount])
    df_mi['Mutual Information'].append(np.mean(results_task))
# Out:
# ('Calc MI FC matrix for subject', 0)
# ('Calc MI FC matrix for subject', 1)
# ('Calc MI FC matrix for subject', 2)
# ('Calc MI FC matrix for subject', 3)
# ('Calc MI FC matrix for subject', 4)
# ('Calc MI FC matrix for subject', 5)
# ('Calc MI FC matrix for subject', 6)
# ('Calc MI FC matrix for subject', 7)
# ('Calc MI FC matrix for subject', 8)
# ('Calc MI FC matrix for subject', 9)
# ('Calc MI FC matrix for subject', 10)
# ('Calc MI FC matrix for subject', 11)
# ('Calc MI FC matrix for subject', 12)
# ('Calc MI FC matrix for subject', 13)
# ('Calc MI FC matrix for subject', 14)
# ('Calc MI FC matrix for subject', 15)
# ('Calc MI FC matrix for subject', 16)
# ('Calc MI FC matrix for subject', 17)
# ('Calc MI FC matrix for subject', 18)
# ('Calc MI FC matrix for subject', 19)
# ('Calc MI FC matrix for subject', 20)
# ('Calc MI FC matrix for subject', 21)
# ('Calc MI FC matrix for subject', 22)
# ('Calc MI FC matrix for subject', 23)
# ('Calc MI FC matrix for subject', 24)
# ('Calc MI FC matrix for subject', 25)
# ('Calc MI FC matrix for subject', 26)
# ('Calc MI FC matrix for subject', 27)
# ('Calc MI FC matrix for subject', 28)
# ('Calc MI FC matrix for subject', 29)
# ('Calc MI FC matrix for subject', 30)
# ('Calc MI FC matrix for subject', 31)
# ('Calc MI FC matrix for subject', 32)
# ('Calc MI FC matrix for subject', 33)
# ('Calc MI FC matrix for subject', 34)
# ('Calc MI FC matrix for subject', 35)
# ('Calc MI FC matrix for subject', 36)
# ('Calc MI FC matrix for subject', 37)
# ('Calc MI FC matrix for subject', 38)
# ('Calc MI FC matrix for subject', 39)
# ('Calc MI FC matrix for subject', 40)
# ('Calc MI FC matrix for subject', 41)
# ('Calc MI FC matrix for subject', 42)
# ('Calc MI FC matrix for subject', 43)
# ('Calc MI FC matrix for subject', 44)
# ('Calc MI FC matrix for subject', 45)
# ('Calc MI FC matrix for subject', 46)
# ('Calc MI FC matrix for subject', 47)
# ('Calc MI FC matrix for subject', 48)
# ('Calc MI FC matrix for subject', 49)
# ('Calc MI FC matrix for subject', 50)
# ('Calc MI FC matrix for subject', 51)
# ('Calc MI FC matrix for subject', 52)
# ('Calc MI FC matrix for subject', 53)
# ('Calc MI FC matrix for subject', 54)
# ('Calc MI FC matrix for subject', 55)
# ('Calc MI FC matrix for subject', 56)
# ('Calc MI FC matrix for subject', 57)
# ('Calc MI FC matrix for subject', 58)
# ('Calc MI FC matrix for subject', 59)
# ('Calc MI FC matrix for subject', 60)
# ('Calc MI FC matrix for subject', 61)
# ('Calc MI FC matrix for subject', 62)
# ('Calc MI FC matrix for subject', 63)
# ('Calc MI FC matrix for subject', 64)
# ('Calc MI FC matrix for subject', 65)
# ('Calc MI FC matrix for subject', 66)
# ('Calc MI FC matrix for subject', 67)
# ('Calc MI FC matrix for subject', 68)
# ('Calc MI FC matrix for subject', 69)
# ('Calc MI FC matrix for subject', 70)
# ('Calc MI FC matrix for subject', 71)
# ('Calc MI FC matrix for subject', 72)
# ('Calc MI FC matrix for subject', 73)
# ('Calc MI FC matrix for subject', 74)
# ('Calc MI FC matrix for subject', 75)
# ('Calc MI FC matrix for subject', 76)
# ('Calc MI FC matrix for subject', 77)
# ('Calc MI FC matrix for subject', 78)
# ('Calc MI FC matrix for subject', 79)
# ('Calc MI FC matrix for subject', 80)
# ('Calc MI FC matrix for subject', 81)
# ('Calc MI FC matrix for subject', 82)
# ('Calc MI FC matrix for subject', 83)
# ('Calc MI FC matrix for subject', 84)
# ('Calc MI FC matrix for subject', 85)
# ('Calc MI FC matrix for subject', 86)
# ('Calc MI FC matrix for subject', 87)
# ('Calc MI FC matrix for subject', 88)
# ('Calc MI FC matrix for subject', 89)
# ('Calc MI FC matrix for subject', 90)
# ('Calc MI FC matrix for subject', 91)
# ('Calc MI FC matrix for subject', 92)
# ('Calc MI FC matrix for subject', 93)
# ('Calc MI FC matrix for subject', 94)
# ('Calc MI FC matrix for subject', 95)
# ('Calc MI FC matrix for subject', 96)
# ('Calc MI FC matrix for subject', 97)
# ('Calc MI FC matrix for subject', 98)
# ('Calc MI FC matrix for subject', 99)
# ('Calc MI FC matrix for subject', 100)
# ('Calc MI FC matrix for subject', 101)
# ('Calc MI FC matrix for subject', 102)
# ('Calc MI FC matrix for subject', 103)
# ('Calc MI FC matrix for subject', 104)
# ('Calc MI FC matrix for subject', 105)
# ('Calc MI FC matrix for subject', 106)
# ('Calc MI FC matrix for subject', 107)
# ('Calc MI FC matrix for subject', 108)
# ('Calc MI FC matrix for subject', 109)
# ('Calc MI FC matrix for subject', 110)
# ('Calc MI FC matrix for subject', 111)
# ('Calc MI FC matrix for subject', 112)
# ('Calc MI FC matrix for subject', 113)
# ('Calc MI FC matrix for subject', 114)
# ('Calc MI FC matrix for subject', 115)
# ('Calc MI FC matrix for subject', 116)
# ('Calc MI FC matrix for subject', 117)
# ('Calc MI FC matrix for subject', 118)
# ('Calc MI FC matrix for subject', 119)
# ('Calc MI FC matrix for subject', 120)
# ('Calc MI FC matrix for subject', 121)
# ('Calc MI FC matrix for subject', 122)
# ('Calc MI FC matrix for subject', 123)
# ('Calc MI FC matrix for subject', 124)
# ('Calc MI FC matrix for subject', 125)
# ('Calc MI FC matrix for subject', 126)
# ('Calc MI FC matrix for subject', 127)
# ('Calc MI FC matrix for subject', 128)
# ('Calc MI FC matrix for subject', 129)
# ('Calc MI FC matrix for subject', 130)
# ('Calc MI FC matrix for subject', 131)
# ('Calc MI FC matrix for subject', 132)
# ('Calc MI FC matrix for subject', 133)
# ('Calc MI FC matrix for subject', 134)
# ('Calc MI FC matrix for subject', 135)
# ('Calc MI FC matrix for subject', 136)
# ('Calc MI FC matrix for subject', 137)
# ('Calc MI FC matrix for subject', 138)
# ('Calc MI FC matrix for subject', 139)
# ('Calc MI FC matrix for subject', 140)
# ('Calc MI FC matrix for subject', 141)
# ('Calc MI FC matrix for subject', 142)
# ('Calc MI FC matrix for subject', 143)
# ('Calc MI FC matrix for subject', 144)
# ('Calc MI FC matrix for subject', 145)
# ('Calc MI FC matrix for subject', 146)
# ('Calc MI FC matrix for subject', 147)
# ('Calc MI FC matrix for subject', 148)
# ('Calc MI FC matrix for subject', 149)
# ('Calc MI FC matrix for subject', 150)
# ('Calc MI FC matrix for subject', 151)
# ('Calc MI FC matrix for subject', 152)
# ('Calc MI FC matrix for subject', 153)
# ('Calc MI FC matrix for subject', 154)
# ('Calc MI FC matrix for subject', 155)
# ('Calc MI FC matrix for subject', 156)
# ('Calc MI FC matrix for subject', 157)
# ('Calc MI FC matrix for subject', 158)
# ('Calc MI FC matrix for subject', 159)
# ('Calc MI FC matrix for subject', 160)
# ('Calc MI FC matrix for subject', 161)
# ('Calc MI FC matrix for subject', 162)
# ('Calc MI FC matrix for subject', 163)
# ('Calc MI FC matrix for subject', 164)
# ('Calc MI FC matrix for subject', 165)
# ('Calc MI FC matrix for subject', 166)
# ('Calc MI FC matrix for subject', 167)
# ('Calc MI FC matrix for subject', 168)
# ('Calc MI FC matrix for subject', 169)
# ('Calc MI FC matrix for subject', 170)
# ('Calc MI FC matrix for subject', 171)
# ('Calc MI FC matrix for subject', 172)
# ('Calc MI FC matrix for subject', 173)
# ('Calc MI FC matrix for subject', 174)
# ('Calc MI FC matrix for subject', 175)

# %%
triu_ind = np.tril_indices(nParcels,k=1)
mi_avg_rest = []
mi_avg_task = []
for s in range(len(subjNums)):
    mi_avg_rest.append(np.mean(mi_mat_rest[:,:,s][triu_ind]))
    mi_avg_task.append(np.mean(mi_mat_task[:,:,s][triu_ind]))

# %%
t, p = stats.ttest_rel(mi_avg_task,mi_avg_rest)
print 'Average mutual information rest', np.mean(mi_avg_rest)
print 'Average mutual information task', np.mean(mi_avg_task)
print 'task v rest',
print '\tt =', t, '| p =', p
# Out:
# Average mutual information rest 0.03652047573195614
# Average mutual information task 0.014888726599789374
# task v rest 	t = -32.36063055928195 | p = 8.9847023711116e-76

# %% [markdown]
# ## Compute average pairwise Mutual Information for task FC and rest FC separately (for each subject)

# %%
df_mi = pd.DataFrame(df_mi)

# Draw a nested boxplot to show bills by day and time
plt.figure(figsize=(5,7))
tmprest = df_mi.loc[df_mi['State']=='Rest']
tmptask = df_mi.loc[df_mi['State']=='Task']
t, p = stats.ttest_rel(tmptask['Mutual Information'],tmprest['Mutual Information'])

sns.boxplot(data=[tmprest['Mutual Information'],tmptask['Mutual Information']],
           palette=["#add8e6","#f08080"],
           meanline=True,showmeans=True,meanprops={'linewidth':5,'color':'k','linestyle':':'},
           medianprops={'linestyle':'-'},sym='',whis=0)
sns.swarmplot(data=[tmprest['Mutual Information'],tmptask['Mutual Information']],
            palette=["#add8e6","#f08080"],
            alpha=0.5)
if str(round(p,3))=="0.0": 
    p = '$p < 0.0001$'
else:
    p = '$p = ' + str(round(p,3))
plt.title('Task vs. rest\nGlobal mutual information',fontsize=28,fontname='FreeSans')
# plt.title('Task versus Rest\nWhole-brain dimensionality\n$t_{175} = ' + str(round(t,3)) + '$ | ' + p,fontsize=24,fontname='FreeSans')
plt.ylabel('Mutual Information',fontsize=24)
plt.xlabel('State',fontsize=24)
plt.xticks(np.arange(2),['Rest','Task'],fontname='FreeSans',fontsize=18)
plt.ylim([np.min(df_mi['Mutual Information'])-np.std(df_mi['Mutual Information']),np.max(df_mi['Mutual Information'])+2*np.std(df_mi['Mutual Information'])]);
plt.yticks(fontsize=18)
plt.tight_layout()
plt.savefig('fMRI4s_GlobalMutualInformation_Replication.pdf')

print 'Task versus rest, global mutual information',
print '\t Dim diff =', np.mean(tmptask['Mutual Information']) - np.mean(tmprest['Mutual Information'])
print '\t t =', t, '| p =', p
# Out:
# Task versus rest, global mutual information 	 Dim diff = -0.0218724366535
# 	 t = -32.36063055928195 | p = $p < 0.0001$

# %% [markdown]
# # Calculate entropy of each region during rest and task

# %%
df_entropy = {}
df_entropy['State'] = []
df_entropy['Subject'] = []
df_entropy['Entropy'] = []
entropy_rest_arr = np.zeros((nParcels,len(subjNums)))
entropy_task_arr = np.zeros((nParcels,len(subjNums)))
for scount in range(len(subjNums)):
    print 'Calculating entropy for rest and task states on subject', scount
    tmp_rest = []
    tmp_task = []
    for roi in range(nParcels):
        entropy_rest_arr[roi,scount] = stats.entropy(np.histogram(restTS[roi,taskGeneralTiming,scount])[0])
        entropy_task_arr[roi,scount] = stats.entropy(np.histogram(taskTS[roi,taskGeneralTiming,scount])[0])
        tmp_rest.append(entropy_rest_arr[roi,scount])
        tmp_task.append(entropy_task_arr[roi,scount])
        
    df_entropy['State'].append('Rest')
    df_entropy['Subject'].append(subjNums[scount])
    df_entropy['Entropy'].append(np.mean(tmp_rest))
    
    df_entropy['State'].append('Task')
    df_entropy['Subject'].append(subjNums[scount])
    df_entropy['Entropy'].append(np.mean(tmp_task))
# Out:
# Calculating entropy for rest and task states on subject 0
# Calculating entropy for rest and task states on subject 1
# Calculating entropy for rest and task states on subject 2
# Calculating entropy for rest and task states on subject 3
# Calculating entropy for rest and task states on subject 4
# Calculating entropy for rest and task states on subject 5
# Calculating entropy for rest and task states on subject 6
# Calculating entropy for rest and task states on subject 7
# Calculating entropy for rest and task states on subject 8
# Calculating entropy for rest and task states on subject 9
# Calculating entropy for rest and task states on subject 10
# Calculating entropy for rest and task states on subject 11
# Calculating entropy for rest and task states on subject 12
# Calculating entropy for rest and task states on subject 13
# Calculating entropy for rest and task states on subject 14
# Calculating entropy for rest and task states on subject 15
# Calculating entropy for rest and task states on subject 16
# Calculating entropy for rest and task states on subject 17
# Calculating entropy for rest and task states on subject 18
# Calculating entropy for rest and task states on subject 19
# Calculating entropy for rest and task states on subject 20
# Calculating entropy for rest and task states on subject 21
# Calculating entropy for rest and task states on subject 22
# Calculating entropy for rest and task states on subject 23
# Calculating entropy for rest and task states on subject 24
# Calculating entropy for rest and task states on subject 25
# Calculating entropy for rest and task states on subject 26
# Calculating entropy for rest and task states on subject 27
# Calculating entropy for rest and task states on subject 28
# Calculating entropy for rest and task states on subject 29
# Calculating entropy for rest and task states on subject 30
# Calculating entropy for rest and task states on subject 31
# Calculating entropy for rest and task states on subject 32
# Calculating entropy for rest and task states on subject 33
# Calculating entropy for rest and task states on subject 34
# Calculating entropy for rest and task states on subject 35
# Calculating entropy for rest and task states on subject 36
# Calculating entropy for rest and task states on subject 37
# Calculating entropy for rest and task states on subject 38
# Calculating entropy for rest and task states on subject 39
# Calculating entropy for rest and task states on subject 40
# Calculating entropy for rest and task states on subject 41
# Calculating entropy for rest and task states on subject 42
# Calculating entropy for rest and task states on subject 43
# Calculating entropy for rest and task states on subject 44
# Calculating entropy for rest and task states on subject 45
# Calculating entropy for rest and task states on subject 46
# Calculating entropy for rest and task states on subject 47
# Calculating entropy for rest and task states on subject 48
# Calculating entropy for rest and task states on subject 49
# Calculating entropy for rest and task states on subject 50
# Calculating entropy for rest and task states on subject 51
# Calculating entropy for rest and task states on subject 52
# Calculating entropy for rest and task states on subject 53
# Calculating entropy for rest and task states on subject 54
# Calculating entropy for rest and task states on subject 55
# Calculating entropy for rest and task states on subject 56
# Calculating entropy for rest and task states on subject 57
# Calculating entropy for rest and task states on subject 58
# Calculating entropy for rest and task states on subject 59
# Calculating entropy for rest and task states on subject 60
# Calculating entropy for rest and task states on subject 61
# Calculating entropy for rest and task states on subject 62
# Calculating entropy for rest and task states on subject 63
# Calculating entropy for rest and task states on subject 64
# Calculating entropy for rest and task states on subject 65
# Calculating entropy for rest and task states on subject 66
# Calculating entropy for rest and task states on subject 67
# Calculating entropy for rest and task states on subject 68
# Calculating entropy for rest and task states on subject 69
# Calculating entropy for rest and task states on subject 70
# Calculating entropy for rest and task states on subject 71
# Calculating entropy for rest and task states on subject 72
# Calculating entropy for rest and task states on subject 73
# Calculating entropy for rest and task states on subject 74
# Calculating entropy for rest and task states on subject 75
# Calculating entropy for rest and task states on subject 76
# Calculating entropy for rest and task states on subject 77
# Calculating entropy for rest and task states on subject 78
# Calculating entropy for rest and task states on subject 79
# Calculating entropy for rest and task states on subject 80
# Calculating entropy for rest and task states on subject 81
# Calculating entropy for rest and task states on subject 82
# Calculating entropy for rest and task states on subject 83
# Calculating entropy for rest and task states on subject 84
# Calculating entropy for rest and task states on subject 85
# Calculating entropy for rest and task states on subject 86
# Calculating entropy for rest and task states on subject 87
# Calculating entropy for rest and task states on subject 88
# Calculating entropy for rest and task states on subject 89
# Calculating entropy for rest and task states on subject 90
# Calculating entropy for rest and task states on subject 91
# Calculating entropy for rest and task states on subject 92
# Calculating entropy for rest and task states on subject 93
# Calculating entropy for rest and task states on subject 94
# Calculating entropy for rest and task states on subject 95
# Calculating entropy for rest and task states on subject 96
# Calculating entropy for rest and task states on subject 97
# Calculating entropy for rest and task states on subject 98
# Calculating entropy for rest and task states on subject 99
# Calculating entropy for rest and task states on subject 100
# Calculating entropy for rest and task states on subject 101
# Calculating entropy for rest and task states on subject 102
# Calculating entropy for rest and task states on subject 103
# Calculating entropy for rest and task states on subject 104
# Calculating entropy for rest and task states on subject 105
# Calculating entropy for rest and task states on subject 106
# Calculating entropy for rest and task states on subject 107
# Calculating entropy for rest and task states on subject 108
# Calculating entropy for rest and task states on subject 109
# Calculating entropy for rest and task states on subject 110
# Calculating entropy for rest and task states on subject 111
# Calculating entropy for rest and task states on subject 112
# Calculating entropy for rest and task states on subject 113
# Calculating entropy for rest and task states on subject 114
# Calculating entropy for rest and task states on subject 115
# Calculating entropy for rest and task states on subject 116
# Calculating entropy for rest and task states on subject 117
# Calculating entropy for rest and task states on subject 118
# Calculating entropy for rest and task states on subject 119
# Calculating entropy for rest and task states on subject 120
# Calculating entropy for rest and task states on subject 121
# Calculating entropy for rest and task states on subject 122
# Calculating entropy for rest and task states on subject 123
# Calculating entropy for rest and task states on subject 124
# Calculating entropy for rest and task states on subject 125
# Calculating entropy for rest and task states on subject 126
# Calculating entropy for rest and task states on subject 127
# Calculating entropy for rest and task states on subject 128
# Calculating entropy for rest and task states on subject 129
# Calculating entropy for rest and task states on subject 130
# Calculating entropy for rest and task states on subject 131
# Calculating entropy for rest and task states on subject 132
# Calculating entropy for rest and task states on subject 133
# Calculating entropy for rest and task states on subject 134
# Calculating entropy for rest and task states on subject 135
# Calculating entropy for rest and task states on subject 136
# Calculating entropy for rest and task states on subject 137
# Calculating entropy for rest and task states on subject 138
# Calculating entropy for rest and task states on subject 139
# Calculating entropy for rest and task states on subject 140
# Calculating entropy for rest and task states on subject 141
# Calculating entropy for rest and task states on subject 142
# Calculating entropy for rest and task states on subject 143
# Calculating entropy for rest and task states on subject 144
# Calculating entropy for rest and task states on subject 145
# Calculating entropy for rest and task states on subject 146
# Calculating entropy for rest and task states on subject 147
# Calculating entropy for rest and task states on subject 148
# Calculating entropy for rest and task states on subject 149
# Calculating entropy for rest and task states on subject 150
# Calculating entropy for rest and task states on subject 151
# Calculating entropy for rest and task states on subject 152
# Calculating entropy for rest and task states on subject 153
# Calculating entropy for rest and task states on subject 154
# Calculating entropy for rest and task states on subject 155
# Calculating entropy for rest and task states on subject 156
# Calculating entropy for rest and task states on subject 157
# Calculating entropy for rest and task states on subject 158
# Calculating entropy for rest and task states on subject 159
# Calculating entropy for rest and task states on subject 160
# Calculating entropy for rest and task states on subject 161
# Calculating entropy for rest and task states on subject 162
# Calculating entropy for rest and task states on subject 163
# Calculating entropy for rest and task states on subject 164
# Calculating entropy for rest and task states on subject 165
# Calculating entropy for rest and task states on subject 166
# Calculating entropy for rest and task states on subject 167
# Calculating entropy for rest and task states on subject 168
# Calculating entropy for rest and task states on subject 169
# Calculating entropy for rest and task states on subject 170
# Calculating entropy for rest and task states on subject 171
# Calculating entropy for rest and task states on subject 172
# Calculating entropy for rest and task states on subject 173
# Calculating entropy for rest and task states on subject 174
# Calculating entropy for rest and task states on subject 175

# %% [markdown]
# ## Compute average Entropy for task and rest states separately (for each subject)

# %%
df_entropy = pd.DataFrame(df_entropy)

# Draw a nested boxplot to show bills by day and time
plt.figure(figsize=(5,7))
tmprest = df_entropy.loc[df_entropy['State']=='Rest']
tmptask = df_entropy.loc[df_entropy['State']=='Task']
t, p = stats.ttest_rel(tmptask['Entropy'],tmprest['Entropy'])
print 'Average mutual information rest', np.mean(tmprest.Entropy.values)
print 'Average mutual information task', np.mean(tmptask.Entropy.values)
print 'task v rest',
print '\tt =', t, '| p =', p

sns.boxplot(data=[tmprest['Entropy'],tmptask['Entropy']],
           palette=["#add8e6","#f08080"],
           meanline=True,showmeans=True,meanprops={'linewidth':5,'color':'k','linestyle':':'},
           medianprops={'linestyle':'-'},sym='',whis=0)
sns.swarmplot(data=[tmprest['Entropy'],tmptask['Entropy']],
            palette=["#add8e6","#f08080"],
            alpha=0.5)
if str(round(p,3))=="0.0": 
    p = '$p < 0.0001$'
else:
    p = '$p = ' + str(round(p,3))
plt.title('Task vs. rest\nGlobal Entropy',fontsize=28,fontname='FreeSans')
# plt.title('Task versus Rest\nWhole-brain dimensionality\n$t_{175} = ' + str(round(t,3)) + '$ | ' + p,fontsize=24,fontname='FreeSans')
plt.ylabel('Entropy',fontsize=24)
plt.xlabel('State',fontsize=24)
plt.xticks(np.arange(2),['Rest','Task'],fontname='FreeSans',fontsize=18)
plt.ylim([np.min(df_entropy['Entropy'])-np.std(df_entropy['Entropy']),np.max(df_entropy['Entropy'])+2*np.std(df_entropy['Entropy'])]);
plt.yticks(fontsize=18)
plt.tight_layout()
plt.savefig('fMRI4s_GlobalEntropy_Replication.pdf')

print 'Task versus rest, average global entropy',
print '\t Dim diff =', np.mean(tmptask['Entropy']) - np.mean(tmprest['Entropy'])
print '\t t =', t, '| p =', p
# Out:
# Average mutual information rest 1.740823770097335
# Average mutual information task 1.7510092042435332
# task v rest 	t = 3.948592510931977 | p = 0.00011377189771355835
# Task versus rest, average global entropy 	 Dim diff = 0.0101854341462
# 	 t = 3.948592510931977 | p = $p < 0.0001$

# %% [markdown]
# # Average joint entropy

# %%
joint_entropy_rest = np.zeros(mi_mat_rest.shape)
joint_entropy_task = np.zeros(mi_mat_task.shape)
df_jointentropy = {}
df_jointentropy['State'] = []
df_jointentropy['Subject'] = []
df_jointentropy['Joint Entropy'] = []
tril_ind = np.tril_indices(nParcels,k=1)
for s in range(len(subjNums)):
    for i in range(nParcels):
        for j in range(nParcels):
            if i >= j: continue
            joint_entropy_rest[i,j,s] = entropy_rest_arr[i,s] + entropy_rest_arr[j,s] - mi_mat_rest[i,j,s]
            joint_entropy_task[i,j,s] = entropy_task_arr[i,s] + entropy_task_arr[j,s] - mi_mat_task[i,j,s]
                
    df_jointentropy['State'].append('Rest')
    df_jointentropy['Joint Entropy'].append(np.mean(joint_entropy_rest[:,:,s][tril_ind]))
    df_jointentropy['Subject'].append(subjNums[s])
    
    df_jointentropy['State'].append('Task')
    df_jointentropy['Joint Entropy'].append(np.mean(joint_entropy_task[:,:,s][tril_ind]))
    df_jointentropy['Subject'].append(subjNums[s])

# %%
df_jointentropy = pd.DataFrame(df_jointentropy)

# Draw a nested boxplot to show bills by day and time
plt.figure(figsize=(5,7))
tmprest = df_jointentropy.loc[df_jointentropy['State']=='Rest']
tmptask = df_jointentropy.loc[df_jointentropy['State']=='Task']
t, p = stats.ttest_rel(tmptask['Joint Entropy'],tmprest['Joint Entropy'])
print 'Average joint entropy rest', np.mean(tmprest['Joint Entropy'].values)
print 'Average joint entropy task', np.mean(tmptask['Joint Entropy'].values)

sns.boxplot(data=[tmprest['Joint Entropy'],tmptask['Joint Entropy']],
           palette=["#add8e6","#f08080"],
           meanline=True,showmeans=True,meanprops={'linewidth':5,'color':'k','linestyle':':'},
           medianprops={'linestyle':'-'},sym='',whis=0)
sns.swarmplot(data=[tmprest['Joint Entropy'],tmptask['Joint Entropy']],
            palette=["#add8e6","#f08080"],
            alpha=0.5)
plt.title('Task vs. rest\nGlobal Joint Entropy',fontsize=28,fontname='FreeSans')
# plt.title('Task versus Rest\nWhole-brain dimensionality\n$t_{175} = ' + str(round(t,3)) + '$ | ' + p,fontsize=24,fontname='FreeSans')
plt.ylabel('Joint Entropy',fontsize=24)
plt.xlabel('State',fontsize=24)
plt.xticks(np.arange(2),['Rest','Task'],fontname='FreeSans',fontsize=18)
plt.ylim([np.min(df_jointentropy['Joint Entropy'])-np.std(df_jointentropy['Joint Entropy']),np.max(df_jointentropy['Joint Entropy'])+2*np.std(df_jointentropy['Joint Entropy'])]);
plt.yticks(fontsize=18)
plt.tight_layout()
plt.savefig('fMRI4s_GlobalJointEntropy_Exploratory.pdf')

print 'Task versus rest, average global entropy'
print '\tEntropy diff =', np.mean(tmptask['Joint Entropy']) - np.mean(tmprest['Joint Entropy'])
print '\t t =', t, '| p =', p
# Out:
# Average joint entropy rest 0.019129686485306555
# Average joint entropy task 0.019241353326232436
# Task versus rest, average global entropy
# 	Entropy diff = 0.000111666840926
# 	 t = 3.939586261105315 | p = 0.00011776463633672888

# %% [markdown]
# # Calculate kurtosis of each region during rest and task

# %%
df_kurtosis = {}
df_kurtosis['State'] = []
df_kurtosis['Subject'] = []
df_kurtosis['Kurtosis'] = []
for scount in range(len(subjNums)):
    print 'Calculating kurtosis for rest and task states on subject', scount
    tmp_rest = []
    tmp_task = []
    for roi in range(nParcels):
        tmp_rest.append(stats.kurtosis(restTS[roi,taskGeneralTiming,scount]))
        tmp_task.append(stats.kurtosis(taskTS[roi,taskGeneralTiming,scount]))
        
    df_kurtosis['State'].append('Rest')
    df_kurtosis['Subject'].append(subjNums[scount])
    df_kurtosis['Kurtosis'].append(np.mean(tmp_rest))
    
    df_kurtosis['State'].append('Task')
    df_kurtosis['Subject'].append(subjNums[scount])
    df_kurtosis['Kurtosis'].append(np.mean(tmp_task))
# Out:
# Calculating kurtosis for rest and task states on subject 0
# Calculating kurtosis for rest and task states on subject 1
# Calculating kurtosis for rest and task states on subject 2
# Calculating kurtosis for rest and task states on subject 3
# Calculating kurtosis for rest and task states on subject 4
# Calculating kurtosis for rest and task states on subject 5
# Calculating kurtosis for rest and task states on subject 6
# Calculating kurtosis for rest and task states on subject 7
# Calculating kurtosis for rest and task states on subject 8
# Calculating kurtosis for rest and task states on subject 9
# Calculating kurtosis for rest and task states on subject 10
# Calculating kurtosis for rest and task states on subject 11
# Calculating kurtosis for rest and task states on subject 12
# Calculating kurtosis for rest and task states on subject 13
# Calculating kurtosis for rest and task states on subject 14
# Calculating kurtosis for rest and task states on subject 15
# Calculating kurtosis for rest and task states on subject 16
# Calculating kurtosis for rest and task states on subject 17
# Calculating kurtosis for rest and task states on subject 18
# Calculating kurtosis for rest and task states on subject 19
# Calculating kurtosis for rest and task states on subject 20
# Calculating kurtosis for rest and task states on subject 21
# Calculating kurtosis for rest and task states on subject 22
# Calculating kurtosis for rest and task states on subject 23
# Calculating kurtosis for rest and task states on subject 24
# Calculating kurtosis for rest and task states on subject 25
# Calculating kurtosis for rest and task states on subject 26
# Calculating kurtosis for rest and task states on subject 27
# Calculating kurtosis for rest and task states on subject 28
# Calculating kurtosis for rest and task states on subject 29
# Calculating kurtosis for rest and task states on subject 30
# Calculating kurtosis for rest and task states on subject 31
# Calculating kurtosis for rest and task states on subject 32
# Calculating kurtosis for rest and task states on subject 33
# Calculating kurtosis for rest and task states on subject 34
# Calculating kurtosis for rest and task states on subject 35
# Calculating kurtosis for rest and task states on subject 36
# Calculating kurtosis for rest and task states on subject 37
# Calculating kurtosis for rest and task states on subject 38
# Calculating kurtosis for rest and task states on subject 39
# Calculating kurtosis for rest and task states on subject 40
# Calculating kurtosis for rest and task states on subject 41
# Calculating kurtosis for rest and task states on subject 42
# Calculating kurtosis for rest and task states on subject 43
# Calculating kurtosis for rest and task states on subject 44
# Calculating kurtosis for rest and task states on subject 45
# Calculating kurtosis for rest and task states on subject 46
# Calculating kurtosis for rest and task states on subject 47
# Calculating kurtosis for rest and task states on subject 48
# Calculating kurtosis for rest and task states on subject 49
# Calculating kurtosis for rest and task states on subject 50
# Calculating kurtosis for rest and task states on subject 51
# Calculating kurtosis for rest and task states on subject 52
# Calculating kurtosis for rest and task states on subject 53
# Calculating kurtosis for rest and task states on subject 54
# Calculating kurtosis for rest and task states on subject 55
# Calculating kurtosis for rest and task states on subject 56
# Calculating kurtosis for rest and task states on subject 57
# Calculating kurtosis for rest and task states on subject 58
# Calculating kurtosis for rest and task states on subject 59
# Calculating kurtosis for rest and task states on subject 60
# Calculating kurtosis for rest and task states on subject 61
# Calculating kurtosis for rest and task states on subject 62
# Calculating kurtosis for rest and task states on subject 63
# Calculating kurtosis for rest and task states on subject 64
# Calculating kurtosis for rest and task states on subject 65
# Calculating kurtosis for rest and task states on subject 66
# Calculating kurtosis for rest and task states on subject 67
# Calculating kurtosis for rest and task states on subject 68
# Calculating kurtosis for rest and task states on subject 69
# Calculating kurtosis for rest and task states on subject 70
# Calculating kurtosis for rest and task states on subject 71
# Calculating kurtosis for rest and task states on subject 72
# Calculating kurtosis for rest and task states on subject 73
# Calculating kurtosis for rest and task states on subject 74
# Calculating kurtosis for rest and task states on subject 75
# Calculating kurtosis for rest and task states on subject 76
# Calculating kurtosis for rest and task states on subject 77
# Calculating kurtosis for rest and task states on subject 78
# Calculating kurtosis for rest and task states on subject 79
# Calculating kurtosis for rest and task states on subject 80
# Calculating kurtosis for rest and task states on subject 81
# Calculating kurtosis for rest and task states on subject 82
# Calculating kurtosis for rest and task states on subject 83
# Calculating kurtosis for rest and task states on subject 84
# Calculating kurtosis for rest and task states on subject 85
# Calculating kurtosis for rest and task states on subject 86
# Calculating kurtosis for rest and task states on subject 87
# Calculating kurtosis for rest and task states on subject 88
# Calculating kurtosis for rest and task states on subject 89
# Calculating kurtosis for rest and task states on subject 90
# Calculating kurtosis for rest and task states on subject 91
# Calculating kurtosis for rest and task states on subject 92
# Calculating kurtosis for rest and task states on subject 93
# Calculating kurtosis for rest and task states on subject 94
# Calculating kurtosis for rest and task states on subject 95
# Calculating kurtosis for rest and task states on subject 96
# Calculating kurtosis for rest and task states on subject 97
# Calculating kurtosis for rest and task states on subject 98
# Calculating kurtosis for rest and task states on subject 99
# Calculating kurtosis for rest and task states on subject 100
# Calculating kurtosis for rest and task states on subject 101
# Calculating kurtosis for rest and task states on subject 102
# Calculating kurtosis for rest and task states on subject 103
# Calculating kurtosis for rest and task states on subject 104
# Calculating kurtosis for rest and task states on subject 105
# Calculating kurtosis for rest and task states on subject 106
# Calculating kurtosis for rest and task states on subject 107
# Calculating kurtosis for rest and task states on subject 108
# Calculating kurtosis for rest and task states on subject 109
# Calculating kurtosis for rest and task states on subject 110
# Calculating kurtosis for rest and task states on subject 111
# Calculating kurtosis for rest and task states on subject 112
# Calculating kurtosis for rest and task states on subject 113
# Calculating kurtosis for rest and task states on subject 114
# Calculating kurtosis for rest and task states on subject 115
# Calculating kurtosis for rest and task states on subject 116
# Calculating kurtosis for rest and task states on subject 117
# Calculating kurtosis for rest and task states on subject 118
# Calculating kurtosis for rest and task states on subject 119
# Calculating kurtosis for rest and task states on subject 120
# Calculating kurtosis for rest and task states on subject 121
# Calculating kurtosis for rest and task states on subject 122
# Calculating kurtosis for rest and task states on subject 123
# Calculating kurtosis for rest and task states on subject 124
# Calculating kurtosis for rest and task states on subject 125
# Calculating kurtosis for rest and task states on subject 126
# Calculating kurtosis for rest and task states on subject 127
# Calculating kurtosis for rest and task states on subject 128
# Calculating kurtosis for rest and task states on subject 129
# Calculating kurtosis for rest and task states on subject 130
# Calculating kurtosis for rest and task states on subject 131
# Calculating kurtosis for rest and task states on subject 132
# Calculating kurtosis for rest and task states on subject 133
# Calculating kurtosis for rest and task states on subject 134
# Calculating kurtosis for rest and task states on subject 135
# Calculating kurtosis for rest and task states on subject 136
# Calculating kurtosis for rest and task states on subject 137
# Calculating kurtosis for rest and task states on subject 138
# Calculating kurtosis for rest and task states on subject 139
# Calculating kurtosis for rest and task states on subject 140
# Calculating kurtosis for rest and task states on subject 141
# Calculating kurtosis for rest and task states on subject 142
# Calculating kurtosis for rest and task states on subject 143
# Calculating kurtosis for rest and task states on subject 144
# Calculating kurtosis for rest and task states on subject 145
# Calculating kurtosis for rest and task states on subject 146
# Calculating kurtosis for rest and task states on subject 147
# Calculating kurtosis for rest and task states on subject 148
# Calculating kurtosis for rest and task states on subject 149
# Calculating kurtosis for rest and task states on subject 150
# Calculating kurtosis for rest and task states on subject 151
# Calculating kurtosis for rest and task states on subject 152
# Calculating kurtosis for rest and task states on subject 153
# Calculating kurtosis for rest and task states on subject 154
# Calculating kurtosis for rest and task states on subject 155
# Calculating kurtosis for rest and task states on subject 156
# Calculating kurtosis for rest and task states on subject 157
# Calculating kurtosis for rest and task states on subject 158
# Calculating kurtosis for rest and task states on subject 159
# Calculating kurtosis for rest and task states on subject 160
# Calculating kurtosis for rest and task states on subject 161
# Calculating kurtosis for rest and task states on subject 162
# Calculating kurtosis for rest and task states on subject 163
# Calculating kurtosis for rest and task states on subject 164
# Calculating kurtosis for rest and task states on subject 165
# Calculating kurtosis for rest and task states on subject 166
# Calculating kurtosis for rest and task states on subject 167
# Calculating kurtosis for rest and task states on subject 168
# Calculating kurtosis for rest and task states on subject 169
# Calculating kurtosis for rest and task states on subject 170
# Calculating kurtosis for rest and task states on subject 171
# Calculating kurtosis for rest and task states on subject 172
# Calculating kurtosis for rest and task states on subject 173
# Calculating kurtosis for rest and task states on subject 174
# Calculating kurtosis for rest and task states on subject 175

# %% [markdown]
# ## Plot kurtosis for task and rest states separately (for each subject)

# %%
df_kurtosis = pd.DataFrame(df_kurtosis)

# Draw a nested boxplot to show bills by day and time
plt.figure(figsize=(5,7))
tmprest = df_kurtosis.loc[df_kurtosis['State']=='Rest']
tmptask = df_kurtosis.loc[df_kurtosis['State']=='Task']
t, p = stats.ttest_rel(tmptask['Kurtosis'],tmprest['Kurtosis'])
print 'Average mutual information rest', np.mean(tmprest.Kurtosis.values)
print 'Average mutual information task', np.mean(tmptask.Kurtosis.values)
print 'task v rest',
print '\tt =', t, '| p =', p

sns.boxplot(data=[tmprest['Kurtosis'],tmptask['Kurtosis']],
           palette=["#add8e6","#f08080"],
           meanline=True,showmeans=True,meanprops={'linewidth':5,'color':'k','linestyle':':'},
           medianprops={'linestyle':'-'},sym='',whis=0)
sns.swarmplot(data=[tmprest['Kurtosis'],tmptask['Kurtosis']],
            palette=["#add8e6","#f08080"],
            alpha=0.5)
if str(round(p,3))=="0.0": 
    p = '$p < 0.0001$'
else:
    p = '$p = ' + str(round(p,3))
plt.title('Task vs. rest\nGlobal Kurtosis',fontsize=28,fontname='FreeSans')
# plt.title('Task versus Rest\nWhole-brain dimensionality\n$t_{175} = ' + str(round(t,3)) + '$ | ' + p,fontsize=24,fontname='FreeSans')
plt.ylabel('Kurtosis',fontsize=24)
plt.xlabel('State',fontsize=24)
plt.xticks(np.arange(2),['Rest','Task'],fontname='FreeSans',fontsize=18)
plt.ylim([np.min(df_kurtosis['Kurtosis'])-np.std(df_kurtosis['Kurtosis']),np.max(df_kurtosis['Kurtosis'])+2*np.std(df_kurtosis['Kurtosis'])]);
plt.yticks(fontsize=18)
plt.tight_layout()
# plt.savefig('fMRI4s_GlobalKurtosis_Replication.pdf')

print 'Task versus rest, average global kurtosis',
print '\t Dim diff =', np.mean(tmptask['Kurtosis']) - np.mean(tmprest['Kurtosis'])
print '\t t =', t, '| p =', p
# Out:
# Average mutual information rest 0.17668477261642604
# Average mutual information task 0.15531011351704013
# task v rest 	t = -2.5991567233324324 | p = 0.010142871405974429
# Task versus rest, average global kurtosis 	 Dim diff = -0.0213746590994
# 	 t = -2.5991567233324324 | p = $p = 0.01
